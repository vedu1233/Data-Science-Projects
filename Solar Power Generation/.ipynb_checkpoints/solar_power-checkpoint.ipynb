# %% [markdown]
# ## Objective
# The variable to be predicted is continuous (energy production). Therefore, this is an Regression project. The primary goal is to model energy production as a function of environmental variables
#
# ## Data Set Description
# The file solarpowergeneration.csv contains the data for this example. Here, the number of variables (columns) is 10, and the number of instances (rows) is 2920. We have the following variables for this analysis:
#
# •	distance_to_solar_noon, in radians.
#
# •	temperature, daily average temperature, in degrees Celsius.
#
# •	wind_direction, daily average wind direction, in degrees (0-360).
#
# •	wind_speed, daily average wind speed, in meters per second.
#
# •	sky_cover, on a five-step scale from 0 to 4, with 0 completely clear and 4 wholly covered.
#
# •	visibility, in kilometers.
#
# •	humidity, in percentage.
#
# •	average_wind_speed, average wind speed during the 3 hours de measure was taken in meters per second.
#
# •	average_pressure, average barometric pressure during the 3 hours the measure was taken in, in mercury inches.
#
# •	power_generated(Target), in Jules for each 3 hours

# %% [markdown]
# # 1) Exploratory data analysis

# %% [markdown]
# ## a) Importing Required Packages

# %%
# Data Manipulation
import pandas as pd 
import numpy as np

# Data Visualisation
import matplotlib.pyplot as plt 
import seaborn as sns 

# Data preprocessing 
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
solar_df = pd.read_csv("solarpowergeneration.csv")

# %%
solar_df.head(10)
# Out:
#    distance-to-solar-noon  temperature  wind-direction  wind-speed  sky-cover  \
# 0                0.859897           69              28         7.5          0
# 1                0.628535           69              28         7.5          0
# 2                0.397172           69              28         7.5          0
# 3                0.165810           69              28         7.5          0
# 4                0.065553           69              28         7.5          0
# 5                0.296915           69              28         7.5          0
# 6                0.528278           69              28         7.5          0
# 7                0.759640           69              28         7.5          0
# 8                0.862113           72              29         6.8          0
# 9                0.630155           72              29         6.8          0
#
#    visibility  humidity  average-wind-speed-(period)  \
# 0        10.0        75                          8.0
# 1        10.0        77                          5.0
# 2        10.0        70                          0.0
# 3        10.0        33                          0.0
# 4        10.0        21                          3.0
# 5        10.0        20                         23.0
# 6        10.0        36                         15.0
# 7        10.0        49                          6.0
# 8        10.0        67                          6.0
# 9        10.0        49                          0.0
#
#    average-pressure-(period)  power-generated
# 0                      29.82                0
# 1                      29.85                0
# 2                      29.89             5418
# 3                      29.91            25477
# 4                      29.89            30069
# 5                      29.85            16280
# 6                      29.83              515
# 7                      29.86                0
# 8                      29.86                0
# 9                      29.87                0

# %%
solar_df.tail(10)
# Out:
#       distance-to-solar-noon  temperature  wind-direction  wind-speed  \
# 2910                0.523627           61              27        15.8
# 2911                0.753512           61              27        15.8
# 2912                0.857875           63              27        13.9
# 2913                0.627401           63              27        13.9
# 2914                0.396927           63              27        13.9
# 2915                0.166453           63              27        13.9
# 2916                0.064020           63              27        13.9
# 2917                0.294494           63              27        13.9
# 2918                0.524968           63              27        13.9
# 2919                0.755442           63              27        13.9
#
#       sky-cover  visibility  humidity  average-wind-speed-(period)  \
# 2910          3        10.0        84                         17.0
# 2911          4        10.0        90                         13.0
# 2912          4        10.0        93                         11.0
# 2913          4        10.0        90                         11.0
# 2914          4        10.0        87                          9.0
# 2915          4        10.0        75                         10.0
# 2916          1        10.0        66                         15.0
# 2917          2        10.0        68                         21.0
# 2918          2        10.0        81                         17.0
# 2919          1        10.0        81                         11.0
#
#       average-pressure-(period)  power-generated
# 2910                      29.85              895
# 2911                      29.87                0
# 2912                      29.86                0
# 2913                      29.86                0
# 2914                      29.90              464
# 2915                      29.93             6995
# 2916                      29.91            29490
# 2917                      29.88            17257
# 2918                      29.87              677
# 2919                      29.90                0

# %%
solar_df.shape
# Out:
# (2920, 10)

# %% [markdown]
# ## b)Descriptive Statistics

# %%
solar_df.describe()
# Out:
#        distance-to-solar-noon  temperature  wind-direction   wind-speed  \
# count             2920.000000  2920.000000     2920.000000  2920.000000
# mean                 0.503294    58.468493       24.953425    10.096986
# std                  0.298024     6.841200        6.915178     4.838185
# min                  0.050401    42.000000        1.000000     1.100000
# 25%                  0.243714    53.000000       25.000000     6.600000
# 50%                  0.478957    59.000000       27.000000    10.000000
# 75%                  0.739528    63.000000       29.000000    13.100000
# max                  1.141361    78.000000       36.000000    26.600000
#
#          sky-cover   visibility     humidity  average-wind-speed-(period)  \
# count  2920.000000  2920.000000  2920.000000                  2919.000000
# mean      1.987671     9.557705    73.513699                    10.129154
# std       1.411978     1.383884    15.077139                     7.261547
# min       0.000000     0.000000    14.000000                     0.000000
# 25%       1.000000    10.000000    65.000000                     5.000000
# 50%       2.000000    10.000000    77.000000                     9.000000
# 75%       3.000000    10.000000    84.000000                    15.000000
# max       4.000000    10.000000   100.000000                    40.000000
#
#        average-pressure-(period)  power-generated
# count                2920.000000      2920.000000
# mean                   30.017760      6979.846233
# std                     0.142006     10312.336413
# min                    29.480000         0.000000
# 25%                    29.920000         0.000000
# 50%                    30.000000       404.000000
# 75%                    30.110000     12723.500000
# max                    30.530000     36580.000000

# %%
solar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   distance-to-solar-noon       2920 non-null   float64
#  1   temperature                  2920 non-null   int64
#  2   wind-direction               2920 non-null   int64
#  3   wind-speed                   2920 non-null   float64
#  4   sky-cover                    2920 non-null   int64
#  5   visibility                   2920 non-null   float64
#  6   humidity                     2920 non-null   int64
#  7   average-wind-speed-(period)  2919 non-null   float64
#  8   average-pressure-(period)    2920 non-null   float64
#  9   power-generated              2920 non-null   int64
# dtypes: float64(5), int64(5)
# memory usage: 228.3 KB

# %%
solar_df.dtypes
# Out:
# distance-to-solar-noon         float64
# temperature                      int64
# wind-direction                   int64
# wind-speed                     float64
# sky-cover                        int64
# visibility                     float64
# humidity                         int64
# average-wind-speed-(period)    float64
# average-pressure-(period)      float64
# power-generated                  int64
# dtype: object

# %%
solar_df.isna().sum() # checking for null values
# Out:
# distance-to-solar-noon         0
# temperature                    0
# wind-direction                 0
# wind-speed                     0
# sky-cover                      0
# visibility                     0
# humidity                       0
# average-wind-speed-(period)    1
# average-pressure-(period)      0
# power-generated                0
# dtype: int64

# %%
#filling null values with median
solar_df["average-wind-speed-(period)"] = solar_df["average-wind-speed-(period)"].fillna(solar_df["average-wind-speed-(period)"].median())

# %%
solar_df.isna().sum()
# Out:
# distance-to-solar-noon         0
# temperature                    0
# wind-direction                 0
# wind-speed                     0
# sky-cover                      0
# visibility                     0
# humidity                       0
# average-wind-speed-(period)    0
# average-pressure-(period)      0
# power-generated                0
# dtype: int64

# %%
# checking for duplicates
solar_df.duplicated().sum()
# Out:
# 0

# %%
# detection of outlier using boxplot

# %%
plt.figure(figsize =(25,8))
solar_df.boxplot()
plt.tight_layout()
plt.show()

# %%
# treat outlier using boxplot method

# %%
def outlier_detection(data,columns): # outlier detection function 
    for col in columns:
        Q1 =data[col].quantile(0.25)
        Q3 =data[col].quantile(0.75)
        iqr = Q3-Q1
        upper = Q3+1.5*iqr
        lower = Q1-1.5*iqr
        data[col] = np.clip(data[col],upper,lower)
    return data

# %%
data_columns = solar_df.columns

# %%
solar_df =outlier_detection(solar_df,data_columns)

# %%
solar_df.describe()
# Out:
#        distance-to-solar-noon  temperature  wind-direction   wind-speed  \
# count             2920.000000  2920.000000     2920.000000  2920.000000
# mean                 0.503294    58.468493       26.254795    10.073288
# std                  0.298024     6.841200        4.089209     4.768867
# min                  0.050401    42.000000       19.000000     1.100000
# 25%                  0.243714    53.000000       25.000000     6.600000
# 50%                  0.478957    59.000000       27.000000    10.000000
# 75%                  0.739528    63.000000       29.000000    13.100000
# max                  1.141361    78.000000       35.000000    22.850000
#
#          sky-cover  visibility     humidity  average-wind-speed-(period)  \
# count  2920.000000      2920.0  2920.000000                  2920.000000
# mean      1.987671        10.0    73.733390                    10.104452
# std       1.411978         0.0    14.435966                     7.184381
# min       0.000000        10.0    36.500000                     0.000000
# 25%       1.000000        10.0    65.000000                     5.000000
# 50%       2.000000        10.0    77.000000                     9.000000
# 75%       3.000000        10.0    84.000000                    15.000000
# max       4.000000        10.0   100.000000                    30.000000
#
#        average-pressure-(period)  power-generated
# count                2920.000000      2920.000000
# mean                   30.017211      6909.688099
# std                     0.139437     10132.725158
# min                    29.635000         0.000000
# 25%                    29.920000         0.000000
# 50%                    30.000000       404.000000
# 75%                    30.110000     12723.500000
# max                    30.395000     31808.750000

# %%
plt.figure(figsize = (15,8))
solar_df.boxplot()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## c)Visualisation

# %%
plt.figure(figsize=(8, 6))
sns.histplot(solar_df['power-generated'], kde=True, color='blue')
plt.title('Distribution of Power Generated')
plt.xlabel('Power Generated')
plt.ylabel('Frequency')
plt.show()

# %%
solar_df.columns
# Out:
# Index(['distance-to-solar-noon', 'temperature', 'wind-direction', 'wind-speed',
#        'sky-cover', 'visibility', 'humidity', 'average-wind-speed-(period)',
#        'average-pressure-(period)', 'power-generated'],
#       dtype='object')

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(data=solar_df, x='temperature', y='power-generated', hue='temperature', palette='viridis')
plt.title('Temperature vs Power Generated')
plt.xlabel('Temperature')
plt.ylabel('Power Generated')
plt.show()

# %%
plt.bar(solar_df["temperature"],solar_df["power-generated"],align ="center")
plt.title("Tempreture VS Power Generated")
plt.xlabel("tempreture")
plt.ylabel("power generated")
plt.tight_layout()

# %%
sns.pairplot(solar_df)
plt.tight_layout()

# %%
plt.figure(figsize =(15,10))
sns.scatterplot(data =solar_df,x ="wind-speed",y="power-generated",color = "red",marker ="o",s =100,hue = "temperature")
plt.title("Wind speed VS Power Generated")
plt.xlabel("Wind Speed")
plt.ylabel("power generated")
plt.tight_layout()
plt.show()

# %%
solar_df.corr()
# Out:
#                              distance-to-solar-noon  temperature  \
# distance-to-solar-noon                     1.000000    -0.145207
# temperature                               -0.145207     1.000000
# wind-direction                            -0.097004     0.333525
# wind-speed                                -0.146349     0.101800
# sky-cover                                 -0.015184    -0.230672
# visibility                                      NaN          NaN
# humidity                                   0.376702    -0.212216
# average-wind-speed-(period)               -0.214628     0.056543
# average-pressure-(period)                  0.083356    -0.439059
# power-generated                           -0.749567     0.133606
#
#                              wind-direction  wind-speed  sky-cover  \
# distance-to-solar-noon            -0.097004   -0.146349  -0.015184
# temperature                        0.333525    0.101800  -0.230672
# wind-direction                     1.000000    0.231166  -0.232814
# wind-speed                         0.231166    1.000000   0.109523
# sky-cover                         -0.232814    0.109523   1.000000
# visibility                              NaN         NaN        NaN
# humidity                          -0.115949   -0.003255   0.396040
# average-wind-speed-(period)        0.154909    0.671810   0.045516
# average-pressure-(period)         -0.200195   -0.384412  -0.086107
# power-generated                    0.150843    0.139647  -0.187133
#
#                              visibility  humidity  \
# distance-to-solar-noon              NaN  0.376702
# temperature                         NaN -0.212216
# wind-direction                      NaN -0.115949
# wind-speed                          NaN -0.003255
# sky-cover                           NaN  0.396040
# visibility                          NaN       NaN
# humidity                            NaN  1.000000
# average-wind-speed-(period)         NaN -0.226988
# average-pressure-(period)           NaN  0.022243
# power-generated                     NaN -0.536943
#
#                              average-wind-speed-(period)  \
# distance-to-solar-noon                         -0.214628
# temperature                                     0.056543
# wind-direction                                  0.154909
# wind-speed                                      0.671810
# sky-cover                                       0.045516
# visibility                                           NaN
# humidity                                       -0.226988
# average-wind-speed-(period)                     1.000000
# average-pressure-(period)                      -0.295259
# power-generated                                 0.273702
#
#                              average-pressure-(period)  power-generated
# distance-to-solar-noon                        0.083356        -0.749567
# temperature                                  -0.439059         0.133606
# wind-direction                               -0.200195         0.150843
# wind-speed                                   -0.384412         0.139647
# sky-cover                                    -0.086107        -0.187133
# visibility                                         NaN              NaN
# humidity                                      0.022243        -0.536943
# average-wind-speed-(period)                  -0.295259         0.273702
# average-pressure-(period)                     1.000000        -0.036538
# power-generated                              -0.036538         1.000000

# %%
solar_df.columns
# Out:
# Index(['distance-to-solar-noon', 'temperature', 'wind-direction', 'wind-speed',
#        'sky-cover', 'visibility', 'humidity', 'average-wind-speed-(period)',
#        'average-pressure-(period)', 'power-generated'],
#       dtype='object')

# %%
solar_df["visibility"].value_counts()
# Out:
# visibility
# 10.0    2920
# Name: count, dtype: int64

# %%
solar_df.drop(columns = "visibility",inplace =True)

# %%
plt.figure(figsize =(10,5))
sns.heatmap(solar_df.corr(),annot =True)
plt.tight_layout()
plt.show()

# %% [raw]
# Strong Negative Correlation:
# Power-Generated and Distance-to-Solar-Noon: The strongest negative correlation is observed between power generated and distance to solar noon (-0.75). This implies that as the distance to solar noon increases, power generation decreases significantly.
# Power-Generated and Average-Pressure (Period): Another strong negative correlation exists between power generated and average pressure (period) (-0.37). This suggests that higher average pressure in the period is associated with lower power generation.
#
# Moderate Negative Correlation:
# Power-Generated and Humidity: There is a moderate negative correlation between power generated and humidity (-0.54). This indicates that higher humidity might result in lower power generation.
#
# Moderate Positive Correlation:
# Average-Wind-Speed (Period) and Power-Generated: Power generated shows a moderate positive correlation with average wind speed in the period (0.27). This suggests that increased wind speed during the period is linked to higher power generation.
#
# Weak Correlation:
# Temperature and Power-Generated: There is a weak correlation between temperature and power generated (0.13). This implies that temperature has a relatively minor influence on power generation.
# Wind Direction and Power-Generated: Wind direction shows a weak correlation with power generated (0.15). This suggests that wind direction plays a less significant role in power generation compared to wind speed.
# Sky-Cover and Power-Generated: The correlation between sky cover and power generated is also weak (-0.19), indicating a limited influence of sky cover on power generation.

# %% [markdown]
# ## d)Important Feature Selection

# %%
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Assume df is your dataset and 'target' is the label column
X = solar_df.drop(columns=['power-generated'])
y = solar_df['power-generated']

# Train a Random Forest Classifier
rf = RandomForestRegressor()
rf.fit(X, y)

# Get feature importance
feature_importance = pd.Series(rf.feature_importances_, index=X.columns)
feature_importance = feature_importance.sort_values(ascending=False)

# Display top features
print(feature_importance)
# Out:
# distance-to-solar-noon         0.834568
# sky-cover                      0.073942
# humidity                       0.023266
# wind-direction                 0.017655
# wind-speed                     0.015941
# average-pressure-(period)      0.011770
# temperature                    0.011729
# average-wind-speed-(period)    0.011128
# dtype: float64

# %%
solar_new = solar_df[["distance-to-solar-noon","sky-cover","humidity","power-generated"]]

# %%
solar_new
# Out:
#       distance-to-solar-noon  sky-cover  humidity  power-generated
# 0                   0.859897          0      75.0              0.0
# 1                   0.628535          0      77.0              0.0
# 2                   0.397172          0      70.0           5418.0
# 3                   0.165810          0      36.5          25477.0
# 4                   0.065553          0      36.5          30069.0
# ...                      ...        ...       ...              ...
# 2915                0.166453          4      75.0           6995.0
# 2916                0.064020          1      66.0          29490.0
# 2917                0.294494          2      68.0          17257.0
# 2918                0.524968          2      81.0            677.0
# 2919                0.755442          1      81.0              0.0
#
# [2920 rows x 4 columns]

# %%
import statsmodels.formula.api as smf

# %%
solar_df.columns
# Out:
# Index(['distance-to-solar-noon', 'temperature', 'wind-direction', 'wind-speed',
#        'sky-cover', 'humidity', 'average-wind-speed-(period)',
#        'average-pressure-(period)', 'power-generated'],
#       dtype='object')

# %%
solar_df = solar_df.rename(columns={
    'distance-to-solar-noon': 'distance_to_solar_noon',
    'temperature': 'temperature',
    'wind-direction': 'wind_direction',
    'wind-speed': 'wind_speed',
    'sky-cover': 'sky_cover',
    'humidity': 'humidity',
    'average-wind-speed-(period)': 'average_wind_speed',
    'average-pressure-(period)': 'average_pressure',
    'power-generated': 'power_generated'
})

# %%
import statsmodels.formula.api as smf
formula = 'power_generated ~ distance_to_solar_noon + temperature + wind_direction + wind_speed + sky_cover + humidity + average_wind_speed + average_pressure'
# Fit the OLS model
model = smf.ols(formula, data=solar_df).fit()
print(model.pvalues.round(5))
# if p value>0.05 variable is not play important role for predicting target variable 
# if p<0.05 variable plays important role for predicting target variables
# Out:
# Intercept                 0.19921
# distance_to_solar_noon    0.00000
# temperature               0.00286
# wind_direction            0.00057
# wind_speed                0.91288
# sky_cover                 0.00000
# humidity                  0.00000
# average_wind_speed        0.00000
# average_pressure          0.01728
# dtype: float64

# %%
# using above conclusion we understood that  'wind speed' is not make impact fot predictung  target variable hence we drop this columns

# %%
solar_df.drop(columns ="wind_speed",inplace =True)

# %%
solar_df.columns
# Out:
# Index(['distance_to_solar_noon', 'temperature', 'wind_direction', 'sky_cover',
#        'humidity', 'average_wind_speed', 'average_pressure',
#        'power_generated'],
#       dtype='object')

# %%
# splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x = solar_df.drop(columns ="power_generated")
y = solar_df["power_generated"]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =42)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((2336, 7), (584, 7), (2336,), (584,))

# %% [markdown]
# ## e) Scaling The Data

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_test_scaled = scaler.fit_transform(x_test)
